# %%
import math
import numpy as np
from sympy import *
import sympy as sp
from sympy.parsing.mathematica import mathematica

print("Digite o valor de h: ")
h = float(input("Digite o valor do h"))
print("Digite o valor de x0: ")
xzero = float(input("Digite o valor de x0"))

def formulaNaoCentrada():

    formulaNC = ((-3/(2*h))*f(xzero)) + ((2/h)*f(xzero + h)) - ((1/(2*h))*f(xzero + 2*h))
    erroTruncamentoMax = derivada1(xzero+(2*h),0) * (h**2/3)    #mudar na func derivada para cada chamada na derivada 1 ou 2
    erroTruncamentoMin = derivada1(xzero,0) * (h**2/3) 
    if(erroTruncamentoMax < erroTruncamentoMin):
        aux = erroTruncamentoMax
        erroTruncamentoMax = erroTruncamentoMin
        erroTruncamentoMin = aux
    print("Pela fórmula não centrada temos o valor de: ", formulaNC)
    print("temos os erros de truncamento máximo dado por {} e o mínimo dado por {}".format(erroTruncamentoMax, erroTruncamentoMin))

def formulaCentrada():
    formulaC = ((f(xzero+h) - f(xzero-h))/(2*h))
    erroTruncamentoMax = derivada1(xzero-h,0) * (h**2/6)    #mudar na func derivada para cada chamada na derivada 1 ou 2
    erroTruncamentoMin = derivada1(xzero+h,0) * (h**2/6) 
    if(erroTruncamentoMax < erroTruncamentoMin):
        aux = erroTruncamentoMax
        erroTruncamentoMax = erroTruncamentoMin
        erroTruncamentoMin = aux
    print("\nPela fórmula centrada temos o valor de: ", formulaC)
    print("temos os erros de truncamento máximo dado por {} e o mínimo dado por {}".format(erroTruncamentoMax, erroTruncamentoMin))



def derivadaSegunda():
    chamado = 1
    aproximacao2 = (f(xzero-h)*f(xzero+h) - (2*f(xzero)))/(h**2)
    erroTruncamentoMax = derivada1(xzero-h, 1) * (h**2/12)    #mudar na func derivada para cada chamada na derivada 1 ou 2
    erroTruncamentoMin = derivada1(xzero+h, 1) * (h**2/12) 
    if(erroTruncamentoMax < erroTruncamentoMin):
        aux = erroTruncamentoMax
        erroTruncamentoMax = erroTruncamentoMin
        erroTruncamentoMin = aux
    print("\nPela aproximação da derivada segunda temos o valor de: ", aproximacao2)
    print("temos os erros de truncamento máximo dado por {} e o mínimo dado por {}".format(erroTruncamentoMax, erroTruncamentoMin))




def f(x):
    return x*(math.e**(-2*x))

def derivada1(x, chamada):
    x= symbols('{}'.format(x))
    # para equações com e, é necesssário colocar math.e
    y = x*(math.e**(-2*x))
    if(chamada == 0):
        derivate = diff(y,x,3)
    else:
        derivate = diff(y,x,4)
    result = str(eval(str(derivate)))  
    if result.find("sin") != -1:
        place = result.find("sin")
        result = result[:place] + "math." + result[place:]
        result = eval(result)
        result = str(result)
    if result.find("cos") != -1:
        place = result.find("cos")
        result = result[:place] + "math." + result[place:]
        result = eval(result)
        result = str(result)
    if result.find("tan") != -1:
        place = result.find("tan")
        result = result[:place] + "math." + result[place:]
        result = eval(result)
        result = str(result)
    if result.find("cosh") != -1:
        place = result.find("cosh")
        result = result[:place] + "math." + result[place:]
        result = eval(result)
        result = str(result)
    if result.find("sinh") != -1:
        place = result.find("sinh")
        result = result[:place] + "math." + result[place:]
        result = eval(result)
        result = str(result)
    
    return (Number(result))

formulaNaoCentrada()
formulaCentrada()
derivadaSegunda()
# Out:
# Digite o valor de h:
# Digite o valor de x0:
# Pela fórmula não centrada temos o valor de:  -0.05470567913571478
# temos os erros de truncamento máximo dado por -0.0002291770115239425 e o mínimo dado por -0.0002442085185164541
#
# Pela fórmula centrada temos o valor de:  -0.05506877601855732
# temos os erros de truncamento máximo dado por -0.0001193107832328824 e o mínimo dado por -0.0001199646145638208
#
# Pela aproximação da derivada segunda temos o valor de:  -7.19240596696057
# temos os erros de truncamento máximo dado por 0.000019994102427303481 e o mínimo dado por -0.00002982769580822063
